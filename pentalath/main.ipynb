# %%
# Objective:
#      5 in a row
# move: 
#      add to empty cell
#      surround capture

import random as rnd
from copy import deepcopy
side = 'B' #{'b' : 0, 'w' : 1}

hex_grid = {
    #(x, y, z) : Long,
    (-6, 6, 0) : 14756229730120285649,
    (-5, 5, 0) : 17294993966705044908,
    (-4, 4, 0) : 11360841376084317915,
    (-3, 3, 0) : 64715400821493339,
    (-2, 2, 0) : 11392466687014964273,
    (-1, 1, 0) : 827832012729673338,
    (0, 0, 0) : 2363175394490800479,
    (1, -1, 0) : 14695126428980817928,
    (2, -2, 0) : 8833834264340910561,
    (3, -3, 0) : 4752494633706821848,
    (4, -4, 0) : 14516678664445486620,
    (5, -5, 0) : 9103259388427434785,
    (6, -6, 0) : 7803284812236529476,


    (-6, 5, 1) : 11597477539298810029,
    (-5, 4, 1) : 4403652703930608877,
    (-4, 3, 1) : 3334700987313879285,
    (-3, 2, 1) : 5217998032787140899,
    (-2, 1, 1) : 12025990812937286854,
    (-1, 0, 1) : 17563424938689068780,
    (0, -1, 1) : 10425383370778439884,
    (1, -2, 1) : 11846409887682226357,
    (2, -3, 1) : 3812491268431640321,
    (3, -4, 1) : 13803803642455526508,
    (4, -5, 1) : 12573300901781314574,
    (5, -6, 1) : 1339936545487722597,


    (-6, 4, 2) : 7661966317029482754,
    (-5, 3, 2) : 14958648361879272208,
    (-4, 2, 2) : 1711633140371236831,
    (-3, 1, 2) : 8388113730989000901,
    (-2, 0, 2) : 341801499625946685,
    (-1, -1, 2) : 2736806691836588504,
    (0, -2, 2) : 4832443112284917601,
    (1, -3, 2) : 7053715411079403212,
    (2, -4, 2) : 10255984520416114090,
    (3, -5, 2) : 12013409289596129128,
    (4, -6, 2) : 18359854379183783685,


    (-6, 3, 3) : 12046367264071699066,
    (-5, 2, 3) : 13930936480516453345,
    (-4, 1, 3) : 11698849862809903826,
    (-3, 0, 3) : 913745333058306689,
    (-2, -1, 3) : 14463912763889403927,
    (-1, -2, 3) : 16472654645371987580,
    (0, -3, 3) : 1630981812972866579,
    (1, -4, 3) : 16774604788261819837,
    (2, -5, 3) : 5334184636616104965,
    (3, -6, 3) : 609270659529100571,


    (-6, 2, 4) : 13750710385927723718,
    (-5, 1, 4) : 14814346280075131541,
    (-4, 0, 4) : 9153401851260489880,
    (-3, -1, 4) : 3903730627434870209,
    (-2, -2, 4) : 5295520165011940449,
    (0, -6, 6) : 902444975978804277,
    (0, -4, 4) : 16349665105643205485,
    (1, -5, 4) : 6551783994372573992,
    (2, -6, 4) : 13221760334023498639,


    (-6, 1, 5) : 6501787189777614562,
    (-5, 0, 5) : 11125633237844994180,
    (-4, -1, 5) : 16030013807908985057,
    (-3, -2, 5) : 10130089266872176871,
    (-2, -3, 5) : 8422622437240023853,
    (-1, -4, 5) : 10027270193708785139,
    (0, -5, 5) : 9345151925983726731,
    (1, -6, 5) : 1275908327215778502,


    (-6, 0, 6) : 11651694224241700949,
    (-5, -1, 6) : 2015955550052725183,
    (-4, -2, 6) : 36462829532900965,
    (0, -6, 6) : 6057911476899991129,
    (-2, -4, 6) : 4152041161842532165,
    (-1, -5, 6) : 7933753893253212962,
    (0, -6, 6) : 4667396805484814222 
}

hex_grid_pieces = {
    #(x, y, z) : Long,
    (-6, 6, 0) : 14756229730120285649,
    (-5, 5, 0) : 17294993966705044908,
    (-4, 4, 0) : 11360841376084317915,
    (-3, 3, 0) : 64715400821493339,
    (-2, 2, 0) : 11392466687014964273,
    (-1, 1, 0) : 827832012729673338,
    (0, 0, 0) : 2363175394490800479,
    (1, -1, 0) : 14695126428980817928,
    (2, -2, 0) : 8833834264340910561,
    (3, -3, 0) : 4752494633706821848,
    (4, -4, 0) : 14516678664445486620,
    (5, -5, 0) : 9103259388427434785,
    (6, -6, 0) : 7803284812236529476,


    (-6, 5, 1) : 11597477539298810029,
    (-5, 4, 1) : 4403652703930608877,
    (-4, 3, 1) : 3334700987313879285,
    (-3, 2, 1) : 5217998032787140899,
    (-2, 1, 1) : 12025990812937286854,
    (-1, 0, 1) : 17563424938689068780,
    (0, -1, 1) : 10425383370778439884,
    (1, -2, 1) : 11846409887682226357,
    (2, -3, 1) : 3812491268431640321,
    (3, -4, 1) : 13803803642455526508,
    (4, -5, 1) : 12573300901781314574,
    (5, -6, 1) : 1339936545487722597,


    (-6, 4, 2) : 7661966317029482754,
    (-5, 3, 2) : 14958648361879272208,
    (-4, 2, 2) : 1711633140371236831,
    (-3, 1, 2) : 8388113730989000901,
    (-2, 0, 2) : 341801499625946685,
    (-1, -1, 2) : 2736806691836588504,
    (0, -2, 2) : 4832443112284917601,
    (1, -3, 2) : 7053715411079403212,
    (2, -4, 2) : 10255984520416114090,
    (3, -5, 2) : 12013409289596129128,
    (4, -6, 2) : 18359854379183783685,


    (-6, 3, 3) : 12046367264071699066,
    (-5, 2, 3) : 13930936480516453345,
    (-4, 1, 3) : 11698849862809903826,
    (-3, 0, 3) : 913745333058306689,
    (-2, -1, 3) : 14463912763889403927,
    (-1, -2, 3) : 16472654645371987580,
    (0, -3, 3) : 1630981812972866579,
    (1, -4, 3) : 16774604788261819837,
    (2, -5, 3) : 5334184636616104965,
    (3, -6, 3) : 609270659529100571,


    (-6, 2, 4) : 13750710385927723718,
    (-5, 1, 4) : 14814346280075131541,
    (-4, 0, 4) : 9153401851260489880,
    (-3, -1, 4) : 3903730627434870209,
    (-2, -2, 4) : 5295520165011940449,
    (0, -6, 6) : 902444975978804277,
    (0, -4, 4) : 16349665105643205485,
    (1, -5, 4) : 6551783994372573992,
    (2, -6, 4) : 13221760334023498639,

#     All pieces
    (-6, 1, 5) : 15059205629503312549,
    (-5, 0, 5) : 15434943676836678362,
    (-4, -1, 5) : 10066543437517168239,
    (-3, -2, 5) : 12355815579803482082,
    (-2, -3, 5) : 6804709287899277189,
    (-1, -4, 5) : 13988528733604824377,
    (0, -5, 5) : 1529366628625134017,
    (1, -6, 5) : 2219451557356060881,


    (-6, 0, 6) : 11651694224241700949,
    (-5, -1, 6) : 2015955550052725183,
    (-4, -2, 6) : 36462829532900965,
    (0, -6, 6) : 6057911476899991129,
    (-2, -4, 6) : 4152041161842532165,
    (-1, -5, 6) : 7933753893253212962,
    (0, -6, 6) : 4667396805484814222 
}

"""Zobrist key for each side

"""
side_zobrist = {'B':5285243159229362636, 'W':9729454471967860433}

"""Dictionary stores location of pieces

"""
piece_position = {
    (0, 0, 0) : side_zobrist['B'],
    (1, -1, 0) : side_zobrist['W'],
    (2, -2, 0) : side_zobrist['B'],
    (3, -3, 0) : side_zobrist['B'],
    (4, -4, 0) : side_zobrist['B'],
    
    (6, -6, 0) : side_zobrist['W'],
    (5, -6, 1) : side_zobrist['W'],
    (4, -6, 2) : side_zobrist['B'],
    (3, -6, 3) : side_zobrist['W'],
    (2, -6, 4) : side_zobrist['W'],
}

"""Move tree

    for every position on the hex grid store all valid to_locations

"""
move_tree_pos = {
    # (from_pos, to_pos): [(depth, dist_to_win, dist_to_loss)]
}


"""Move tree

    for every position on the hex grid store all valid to_locations

"""
move_tree_depth = {
    # (from_pos, depth): [(to_pos, dist_to_win, dist_to_loss)]
}

"""Store which moves have been made

"""
move_history = {
    
}

tt = {}

move_counter = 0

# %%
def evalution(win, loss):
    return abs(win-loss) >= 3 #threshold

def prune(node):
    del move_tree[p]

# %%
def cube_to_axial(cube):
    q = cube[:, 0]
    r = cube[:, 2]
    return (q, r)

def axial_to_cube(hexchoord):
    z = hexchoord[0]
    x = hexchoord[1]
    y = -x-z
    return (x, y, z)

# %%
def pos_occupied(x, y, z):
    global piece_position
    if (x, y, z) in piece_position:
        return True
    return False
    
def make_move(to_position):
    global piece_position
    global move_history
    global move_counter
    global side
    piece_position[to_position] = side_zobrist[side]
    move_history[move_counter, to_position] = [ side]
    move_counter += 1
    
def undo_make_move(to_position):
    global piece_position
    global move_history
    global move_counter
    global side
    del piece_position[to_position]
#     print(move_history)
    move_counter -= 1
    del move_history[move_counter, to_position]
    
def reset():
    global piece_position
    piece_position = {}
    
    global move_history
    move_history = {}
    
    global move_counter
    move_counter = 0
    
    global hex_grid
#     global hex_grid_temp
    
#     hex_grid = hex_grid_temp
    
    global side
    side = 'B'      
            
            
def horizontal_win(x, y, z):
    if (x + 4) > (6 - z):
        return False
#     print('hi1') #(-1, -2, 3) --> -1, 0, 1, 2, 3 == -2, -3, -4, -5, -6 == 2
    if pos_occupied(x, y, z) and \
        pos_occupied(x+1, y-1, z) and \
        pos_occupied(x+2, y-2, z) and \
        pos_occupied(x+3, y-3, z) and \
        pos_occupied(x+4, y-4, z) and \
        (piece_position[(x, y, z)] == \
        piece_position[(x+1, y-1, z)] == \
        piece_position[(x+2, y-2, z)] == \
        piece_position[(x+3, y-3, z)] == \
        piece_position[(x+4, y-4, z)]):
        return True, (x, y, z), (x+1, y-1, z), (x+2, y-2, z), (x+3, y-3, z), (x+4, y-4, z)
    return False
    
def vertical_win_left(x, y, z):
    if  (z < 4 and x > 2) or  y - 4  < -(6 + x):
        return False
#     print('hi2')
    if pos_occupied(x, y, z) and \
        pos_occupied(x, y-1, z+1) and \
        pos_occupied(x, y-2, z+2) and \
        pos_occupied(x, y-3, z+3) and \
        pos_occupied(x, y-4, z+4) and \
        (piece_position[(x, y, z)] == \
        piece_position[(x, y-1, z+1)] == \
        piece_position[(x, y-2, z+2)] == \
        piece_position[(x, y-3, z+3)] == \
        piece_position[(x, y-4, z+4)]):
        return True, (x, y, z), (x, y-1, z+1), (x, y-2, z+2), (x, y-3, z+3), (x, y-4, z+4)
    return False

def vertical_win_right(x, y, z):
    if  (z < 4 and y > 2) or  x - 4  < -(6 + y):
        return False
    if pos_occupied(x, y, z) and \
        pos_occupied(x-1, y, z+1) and \
        pos_occupied(x-2, y, z+2) and \
        pos_occupied(x-3, y, z+3) and \
        pos_occupied(x-4, y, z+4) and \
        (piece_position[(x, y, z)] == \
        piece_position[(x-1, y, z+1)] == \
        piece_position[(x-2, y, z+2)] == \
        piece_position[(x-3, y, z+3)] == \
        piece_position[(x-4, y, z+4)]):
        return True, (x, y, z), (x-1, y, z+1), (x-2, y, z+2), (x-3, y, z+3), (x-4, y, z+4)
    return False
    
def check_win():
    for j in range(7): # row, z
        for i in range(-6, 7-j): # col, y, x
            x, y, z = axial_to_cube((j, i))
#             print(x, y, z)
            if horizontal_win(x, y, z):
                return horizontal_win(x, y, z)
            elif vertical_win_left(x, y, z):
                return vertical_win_left(x, y, z)
            elif vertical_win_right(x, y, z):
                return vertical_win_right(x, y, z)
            
    return False


def printBoard(board):
    row = ''
    tab = ' '
    
    """ Print board by converting axial to cube positions
    
    """
    for j in range(7): # row, z
        for i in range(-6, 7-j): # col, y, x
            x, y, z = axial_to_cube((j, i))
            
            if pos_occupied(x, y, z):
                if piece_position[(x, y, z)] == 5285243159229362636:
                    row += 'B'
                else:
                    row += 'W'
            else:
                row += '_'
                
            row += ' '
            
        row += '\n'
        row += tab
        tab += ' '

        
        
    print(row)

# %%
# piece_position[(-6, 6, 0)]
# tt = {} # ( (depth, old_board) :[new_board])

# %%
""" Create a zobrist key for the entire board

"""
def toZobrist(hex_grid):
    zobrist_key = 0
    for key in hex_grid:
        zobrist_key ^= hex_grid[key]
        
        if key in piece_position:
#             print(piece_position)
            zobrist_key ^= int(piece_position[key])
            
    return zobrist_key

toZobrist(hex_grid)
# Out:
# 4288134929687727839

# %%
piece_position[(0,0,0)] ^ 9729454471967860433
# Out:
# 14870045864219842333

# %%
def sequentialPlay(depth):
    global hex_grid
    global side
#     global tt
    new_zobrist = 0
    
    hex_grid_temp = deepcopy(hex_grid) # copy without references
    
    """Play a sequential game, play row by value

    """
    if check_win():
        print('Already won?: ', check_win(), '\n')
        printBoard(hex_grid)
    else:
        for position in hex_grid:
            x, y, z = position
            moveMade = False

            if not pos_occupied(x, y, z):
                make_move((x, y, z))
                moveMade = True
                
                new_zobrist = toZobrist(hex_grid) ^ rnd.getrandbits(64)

                if check_win():
                    print('Won', (x, y, z), check_win())
                    undo_make_move((x, y, z))
                else:
                    print('No Win', (x, y, z), check_win())
                printBoard(hex_grid)
                tt.setdefault((depth, toZobrist(hex_grid)), []).append(new_zobrist)

            if moveMade:
                undo_make_move((x, y, z))
    
    return move_history

def randomPlay():
    global hex_grid
    global side
    hex_grid_temp = deepcopy(hex_grid) # copy without references

    """Play a random game

    """
    if check_win():
        print('Already won?: ', check_win(), '\n')
        printBoard(hex_grid)
    else:
        for n in range(len(hex_grid)): #100
            moveMade = False
            while not moveMade:
                position = rnd.sample(list(hex_grid), 1) #100
                x, y, z = position[0]

                if not pos_occupied(x, y, z):
                    make_move((x, y, z))
                    moveMade = True
                    printBoard(hex_grid)

                    if check_win():
                        print('Won', (x, y, z), check_win())
                        break
                    else:
                        print('No Win', (x, y, z), check_win())

                    side = 'W' if side == 'B' else 'B' # change sides
                        
                    break

    print(move_history)
    
    return move_history   
    
def randomPlay2():
    global hex_grid
    global side
    hex_grid_temp = deepcopy(hex_grid) # copy without references

    x, y, z = 0, 0, 0
    """Play a random game

    """
    if check_win():
        print('Already won?: ', check_win(), '\n')
        printBoard(hex_grid)
    else:
        for n in range(len(hex_grid)+1): #100
            i, j = 0, 0

            valid_move = False
            while not valid_move: 
                i = rnd.randint(-6,6)
                j = rnd.randint(-6, 6-i)
                x, y, z = axial_to_cube((j, i))
                if (x, y, z) in hex_grid and not pos_occupied(x, y, z):
                    valid_move = True
                    make_move((x, y, z))
                    break

            printBoard(hex_grid)

            if check_win():
                print('Won', (x, y, z), check_win())
                break
            else:
                print('No Win', (x, y, z), check_win())

            side = 'W' if side == 'B' else 'B' # change sides

    print(move_history)
    
    return move_history

# randomPlay()
sequentialPlay(0)

reset()

# import numpy as np
# np.array(hex_grid)[0]
# Out:
# No Win (-6, 6, 0) False
# B _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-5, 5, 0) False
# _ B _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-4, 4, 0) False
# _ _ B _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-3, 3, 0) False
# _ _ _ B _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-2, 2, 0) False
# _ _ _ _ B _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-1, 1, 0) False
# _ _ _ _ _ B B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (5, -5, 0) False
# _ _ _ _ _ _ B W B B B B W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-6, 5, 1) False
# _ _ _ _ _ _ B W B B B _ W
#  B _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-5, 4, 1) False
# _ _ _ _ _ _ B W B B B _ W
#  _ B _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-4, 3, 1) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ B _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-3, 2, 1) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ B _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-2, 1, 1) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ B _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-1, 0, 1) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ B _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (0, -1, 1) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ B _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (1, -2, 1) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ B _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (2, -3, 1) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ B _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (3, -4, 1) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ B _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (4, -5, 1) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ B W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-6, 4, 2) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   B _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-5, 3, 2) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ B _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-4, 2, 2) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ B _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-3, 1, 2) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ B _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-2, 0, 2) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ B _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-1, -1, 2) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ B _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (0, -2, 2) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ B _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (1, -3, 2) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ B _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (2, -4, 2) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ B _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (3, -5, 2) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ B B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-6, 3, 3) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    B _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-5, 2, 3) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ B _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-4, 1, 3) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ B _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-3, 0, 3) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ B _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-2, -1, 3) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ B _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-1, -2, 3) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ B _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (0, -3, 3) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ B _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (1, -4, 3) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ B _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (2, -5, 3) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ B W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-6, 2, 4) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     B _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-5, 1, 4) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ B _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-4, 0, 4) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ B _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-3, -1, 4) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ B _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-2, -2, 4) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ B _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (0, -6, 6) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ B
#
# No Win (0, -4, 4) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ B _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (1, -5, 4) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ B W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-6, 1, 5) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      B _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-5, 0, 5) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ B _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-4, -1, 5) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ B _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-3, -2, 5) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ B _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-2, -3, 5) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ B _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-1, -4, 5) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ B _ _
#       _ _ _ _ _ _ _
#
# No Win (0, -5, 5) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ B _
#       _ _ _ _ _ _ _
#
# No Win (1, -6, 5) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ B
#       _ _ _ _ _ _ _
#
# No Win (-6, 0, 6) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       B _ _ _ _ _ _
#
# No Win (-5, -1, 6) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ B _ _ _ _ _
#
# No Win (-4, -2, 6) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ B _ _ _ _
#
# No Win (-2, -4, 6) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ B _ _
#
# No Win (-1, -5, 6) False
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ B _

# %%
tt
# Out:
# {(0, 8276058491019771667): [719825122207439018,
#   12931997308911480634,
#   14509919434985149417,
#   2098162971556876332,
#   5393079441559460246,
#   14110084975963602703,
#   6012460085400073876,
#   16090762351040683271,
#   5878749058885152928,
#   1573083869568667748,
#   13252074862953868101,
#   8405422087096558453,
#   14906743448778924151,
#   7783292717992787413,
#   6802652706541649061,
#   17111212793500203280,
#   11956101090796291107,
#   10620346997031240518,
#   5762025329249081141,
#   3873263320955485404,
#   5916473614636302981,
#   15028341192253909128,
#   517677946315925541,
#   17930385531108769488,
#   8075161879215196029,
#   4852021688123356694,
#   1194714849131664439,
#   16338598530188324889,
#   4912546005551456293,
#   17148339239908272731,
#   2055134119950120198,
#   15368258969242039472,
#   16749103517582376558,
#   8780123334421737780,
#   2935085173049050456,
#   651239943921713895,
#   5572781420951510116,
#   18044047169873733371,
#   15788700532235206609,
#   2296171230502792272,
#   6218456224305911804,
#   8604931315810566797,
#   3365482108403529857,
#   1364916009647819284,
#   14151396173315833896,
#   10051189862322429543,
#   8222918848325499034,
#   14503125109793668573,
#   17623431621056890065,
#   3652995060712089799,
#   9783903058079104477,
#   17757931129675719908,
#   5627182278291525112,
#   10457387842317946701,
#   11527190470456016492,
#   17800229681862686297,
#   126493055882142446,
#   10264743673116325907]}

# %%
def main(select):
    print(select)
    if select == 1: return 1 # h vs h
    elif select == 2: return 2 # m vs h
    elif select == 3: return 3 # h vs m
    elif select == 4: print (4) # m vs m
    return 0
    
if '__name__' == '__main__':
    main(4)

# %%
# import time

# print ("time.time(): %f " % time.time())
# print (time.ctime(int( 1514962335.2237754)))
# print (time.asctime( time.localtime(1516961409.8324103) ))
# print ((time.time() - 1514962335.2237754)/60/60)

# %%
# d = [rnd.randint(0, 10) for i in range(10)]

# import sys

# CURSOR_UP_ONE = '\x1b[1A'
# ERASE_LINE = '\x1b[2K'

# counter = ''
# for i in d:
#     counter += '-'
#     sys.stdout.write(counter + '\n'+CURSOR_UP_ONE)
#     sys.stdout.write(ERASE_LINE)
