# %%
# Objective:
#      5 in a row
# move: 
#      add to empty cell
#      surround capture

import random as rnd
from copy import deepcopy
side = 'B' #{'b' : 0, 'w' : 1}

hex_grid = {
    #(x, y, z) : Long,
    (-6, 6, 0) : 14756229730120285649,
    (-5, 5, 0) : 17294993966705044908,
    (-4, 4, 0) : 11360841376084317915,
    (-3, 3, 0) : 64715400821493339,
    (-2, 2, 0) : 11392466687014964273,
    (-1, 1, 0) : 827832012729673338,
    (0, 0, 0) : 2363175394490800479,
    (1, -1, 0) : 14695126428980817928,
    (2, -2, 0) : 8833834264340910561,
    (3, -3, 0) : 4752494633706821848,
    (4, -4, 0) : 14516678664445486620,
    (5, -5, 0) : 9103259388427434785,
    (6, -6, 0) : 7803284812236529476,


    (-6, 5, 1) : 11597477539298810029,
    (-5, 4, 1) : 4403652703930608877,
    (-4, 3, 1) : 3334700987313879285,
    (-3, 2, 1) : 5217998032787140899,
    (-2, 1, 1) : 12025990812937286854,
    (-1, 0, 1) : 17563424938689068780,
    (0, -1, 1) : 10425383370778439884,
    (1, -2, 1) : 11846409887682226357,
    (2, -3, 1) : 3812491268431640321,
    (3, -4, 1) : 13803803642455526508,
    (4, -5, 1) : 12573300901781314574,
    (5, -6, 1) : 1339936545487722597,


    (-6, 4, 2) : 7661966317029482754,
    (-5, 3, 2) : 14958648361879272208,
    (-4, 2, 2) : 1711633140371236831,
    (-3, 1, 2) : 8388113730989000901,
    (-2, 0, 2) : 341801499625946685,
    (-1, -1, 2) : 2736806691836588504,
    (0, -2, 2) : 4832443112284917601,
    (1, -3, 2) : 7053715411079403212,
    (2, -4, 2) : 10255984520416114090,
    (3, -5, 2) : 12013409289596129128,
    (4, -6, 2) : 18359854379183783685,


    (-6, 3, 3) : 12046367264071699066,
    (-5, 2, 3) : 13930936480516453345,
    (-4, 1, 3) : 11698849862809903826,
    (-3, 0, 3) : 913745333058306689,
    (-2, -1, 3) : 14463912763889403927,
    (-1, -2, 3) : 16472654645371987580,
    (0, -3, 3) : 1630981812972866579,
    (1, -4, 3) : 16774604788261819837,
    (2, -5, 3) : 5334184636616104965,
    (3, -6, 3) : 609270659529100571,


    (-6, 2, 4) : 13750710385927723718,
    (-5, 1, 4) : 14814346280075131541,
    (-4, 0, 4) : 9153401851260489880,
    (-3, -1, 4) : 3903730627434870209,
    (-2, -2, 4) : 5295520165011940449,
    (0, -6, 6) : 902444975978804277,
    (0, -4, 4) : 16349665105643205485,
    (1, -5, 4) : 6551783994372573992,
    (2, -6, 4) : 13221760334023498639,


    (-6, 1, 5) : 6501787189777614562,
    (-5, 0, 5) : 11125633237844994180,
    (-4, -1, 5) : 16030013807908985057,
    (-3, -2, 5) : 10130089266872176871,
    (-2, -3, 5) : 8422622437240023853,
    (-1, -4, 5) : 10027270193708785139,
    (0, -5, 5) : 9345151925983726731,
    (1, -6, 5) : 1275908327215778502,


    (-6, 0, 6) : 11651694224241700949,
    (-5, -1, 6) : 2015955550052725183,
    (-4, -2, 6) : 36462829532900965,
    (0, -6, 6) : 6057911476899991129,
    (-2, -4, 6) : 4152041161842532165,
    (-1, -5, 6) : 7933753893253212962,
    (0, -6, 6) : 4667396805484814222 
}

hex_grid_pieces = {
    #(x, y, z) : Long,
    (-6, 6, 0) : 14756229730120285649,
    (-5, 5, 0) : 17294993966705044908,
    (-4, 4, 0) : 11360841376084317915,
    (-3, 3, 0) : 64715400821493339,
    (-2, 2, 0) : 11392466687014964273,
    (-1, 1, 0) : 827832012729673338,
    (0, 0, 0) : 2363175394490800479,
    (1, -1, 0) : 14695126428980817928,
    (2, -2, 0) : 8833834264340910561,
    (3, -3, 0) : 4752494633706821848,
    (4, -4, 0) : 14516678664445486620,
    (5, -5, 0) : 9103259388427434785,
    (6, -6, 0) : 7803284812236529476,


    (-6, 5, 1) : 11597477539298810029,
    (-5, 4, 1) : 4403652703930608877,
    (-4, 3, 1) : 3334700987313879285,
    (-3, 2, 1) : 5217998032787140899,
    (-2, 1, 1) : 12025990812937286854,
    (-1, 0, 1) : 17563424938689068780,
    (0, -1, 1) : 10425383370778439884,
    (1, -2, 1) : 11846409887682226357,
    (2, -3, 1) : 3812491268431640321,
    (3, -4, 1) : 13803803642455526508,
    (4, -5, 1) : 12573300901781314574,
    (5, -6, 1) : 1339936545487722597,


    (-6, 4, 2) : 7661966317029482754,
    (-5, 3, 2) : 14958648361879272208,
    (-4, 2, 2) : 1711633140371236831,
    (-3, 1, 2) : 8388113730989000901,
    (-2, 0, 2) : 341801499625946685,
    (-1, -1, 2) : 2736806691836588504,
    (0, -2, 2) : 4832443112284917601,
    (1, -3, 2) : 7053715411079403212,
    (2, -4, 2) : 10255984520416114090,
    (3, -5, 2) : 12013409289596129128,
    (4, -6, 2) : 18359854379183783685,


    (-6, 3, 3) : 12046367264071699066,
    (-5, 2, 3) : 13930936480516453345,
    (-4, 1, 3) : 11698849862809903826,
    (-3, 0, 3) : 913745333058306689,
    (-2, -1, 3) : 14463912763889403927,
    (-1, -2, 3) : 16472654645371987580,
    (0, -3, 3) : 1630981812972866579,
    (1, -4, 3) : 16774604788261819837,
    (2, -5, 3) : 5334184636616104965,
    (3, -6, 3) : 609270659529100571,


    (-6, 2, 4) : 13750710385927723718,
    (-5, 1, 4) : 14814346280075131541,
    (-4, 0, 4) : 9153401851260489880,
    (-3, -1, 4) : 3903730627434870209,
    (-2, -2, 4) : 5295520165011940449,
    (0, -6, 6) : 902444975978804277,
    (0, -4, 4) : 16349665105643205485,
    (1, -5, 4) : 6551783994372573992,
    (2, -6, 4) : 13221760334023498639,

#     All pieces
    (-6, 1, 5) : 15059205629503312549,
    (-5, 0, 5) : 15434943676836678362,
    (-4, -1, 5) : 10066543437517168239,
    (-3, -2, 5) : 12355815579803482082,
    (-2, -3, 5) : 6804709287899277189,
    (-1, -4, 5) : 13988528733604824377,
    (0, -5, 5) : 1529366628625134017,
    (1, -6, 5) : 2219451557356060881,


    (-6, 0, 6) : 11651694224241700949,
    (-5, -1, 6) : 2015955550052725183,
    (-4, -2, 6) : 36462829532900965,
    (0, -6, 6) : 6057911476899991129,
    (-2, -4, 6) : 4152041161842532165,
    (-1, -5, 6) : 7933753893253212962,
    (0, -6, 6) : 4667396805484814222 
}

"""Zobrist key for each side

"""
side_zobrist = {'B':5285243159229362636, 'W':9729454471967860433}

"""Dictionary stores location of pieces

"""
piece_position = {
    (0, 0, 0) : side_zobrist['B'],
    (1, -1, 0) : side_zobrist['W'],
    (2, -2, 0) : side_zobrist['B'],
    (3, -3, 0) : side_zobrist['B'],
    (4, -4, 0) : side_zobrist['B'],
    
    (6, -6, 0) : side_zobrist['W'],
    (5, -6, 1) : side_zobrist['W'],
    (4, -6, 2) : side_zobrist['B'],
    (3, -6, 3) : side_zobrist['W'],
    (2, -6, 4) : side_zobrist['W'],
}

"""Move tree

    for every position on the hex grid store all valid to_locations

"""
move_tree_pos = {
    # (from_pos, to_pos): [(depth, dist_to_win, dist_to_loss)]
}


"""Move tree

    for every position on the hex grid store all valid to_locations

"""
move_tree_depth = {
    # (from_pos, depth): [(to_pos, dist_to_win, dist_to_loss)]
}

"""Store which moves have been made

"""
move_history = {
    
}

tt = {}

move_counter = 0

# %%
def evalution(win, loss):
    return abs(win-loss) >= 3 #threshold

def prune(node):
    del move_tree[p]

# %%
def cube_to_axial(cube):
    q = cube[:, 0]
    r = cube[:, 2]
    return (q, r)

def axial_to_cube(hexchoord):
    z = hexchoord[0]
    x = hexchoord[1]
    y = -x-z
    return (x, y, z)

# %%
def pos_occupied(x, y, z):
    global piece_position
    if (x, y, z) in piece_position:
        return True
    return False
    
def make_move(to_position):
    global piece_position
    global move_history
    global move_counter
    global side
    piece_position[to_position] = side_zobrist[side]
    move_history[move_counter, to_position] = [ side]
    move_counter += 1
    
def undo_make_move(to_position):
    global piece_position
    global move_history
    global move_counter
    global side
    del piece_position[to_position]
#     print(move_history)
    move_counter -= 1
    del move_history[move_counter, to_position]
    
def reset():
    global piece_position
    piece_position = {}
    
    global move_history
    move_history = {}
    
    global move_counter
    move_counter = 0
    
    global hex_grid
#     global hex_grid_temp
    
#     hex_grid = hex_grid_temp
    
    global side
    side = 'B'      
            
            
def horizontal_win(x, y, z):
    if (x + 4) > (6 - z):
        return False
#     print('hi1') #(-1, -2, 3) --> -1, 0, 1, 2, 3 == -2, -3, -4, -5, -6 == 2
    if pos_occupied(x, y, z) and \
        pos_occupied(x+1, y-1, z) and \
        pos_occupied(x+2, y-2, z) and \
        pos_occupied(x+3, y-3, z) and \
        pos_occupied(x+4, y-4, z) and \
        (piece_position[(x, y, z)] == \
        piece_position[(x+1, y-1, z)] == \
        piece_position[(x+2, y-2, z)] == \
        piece_position[(x+3, y-3, z)] == \
        piece_position[(x+4, y-4, z)]):
        return True, (x, y, z), (x+1, y-1, z), (x+2, y-2, z), (x+3, y-3, z), (x+4, y-4, z)
    return False
    
def vertical_win_left(x, y, z):
    if  (z < 4 and x > 2) or  y - 4  < -(6 + x):
        return False
#     print('hi2')
    if pos_occupied(x, y, z) and \
        pos_occupied(x, y-1, z+1) and \
        pos_occupied(x, y-2, z+2) and \
        pos_occupied(x, y-3, z+3) and \
        pos_occupied(x, y-4, z+4) and \
        (piece_position[(x, y, z)] == \
        piece_position[(x, y-1, z+1)] == \
        piece_position[(x, y-2, z+2)] == \
        piece_position[(x, y-3, z+3)] == \
        piece_position[(x, y-4, z+4)]):
        return True, (x, y, z), (x, y-1, z+1), (x, y-2, z+2), (x, y-3, z+3), (x, y-4, z+4)
    return False

def vertical_win_right(x, y, z):
    if  (z < 4 and y > 2) or  x - 4  < -(6 + y):
        return False
    if pos_occupied(x, y, z) and \
        pos_occupied(x-1, y, z+1) and \
        pos_occupied(x-2, y, z+2) and \
        pos_occupied(x-3, y, z+3) and \
        pos_occupied(x-4, y, z+4) and \
        (piece_position[(x, y, z)] == \
        piece_position[(x-1, y, z+1)] == \
        piece_position[(x-2, y, z+2)] == \
        piece_position[(x-3, y, z+3)] == \
        piece_position[(x-4, y, z+4)]):
        return True, (x, y, z), (x-1, y, z+1), (x-2, y, z+2), (x-3, y, z+3), (x-4, y, z+4)
    return False
    
def check_win():
    for j in range(7): # row, z
        for i in range(-6, 7-j): # col, y, x
            x, y, z = axial_to_cube((j, i))
#             print(x, y, z)
            if horizontal_win(x, y, z):
                return horizontal_win(x, y, z)
            elif vertical_win_left(x, y, z):
                return vertical_win_left(x, y, z)
            elif vertical_win_right(x, y, z):
                return vertical_win_right(x, y, z)
            
    return False


def printBoard(board):
    row = ''
    tab = ' '
    
    """ Print board by converting axial to cube positions
    
    """
    for j in range(7): # row, z
        for i in range(-6, 7-j): # col, y, x
            x, y, z = axial_to_cube((j, i))
            
            if pos_occupied(x, y, z):
                if piece_position[(x, y, z)] == 5285243159229362636:
                    row += 'B'
                else:
                    row += 'W'
            else:
                row += '_'
                
            row += ' '
            
        row += '\n'
        row += tab
        tab += ' '
        
    print(row)
#     return row

"""Convert board to zobrist grid

"""
def board_to_zobrist():
    zb = 0
    hex_temp = {}
    zobrist_convert = 0
    
    """Convert board to zobrist
    
    """
    for pos_zobrist in hex_grid:     
        if pos_zobrist in piece_position:
            zobrist_convert = hex_grid[pos_zobrist] ^ piece_position[pos_zobrist]
            hex_temp.setdefault(pos_zobrist, []).append(zobrist_convert)
        else:
            hex_temp.setdefault(pos_zobrist, []).append(hex_grid[pos_zobrist])  
        zb ^= hex_grid[pos_zobrist]
        
    return hex_temp
    
"""Print board based on the zobrist poistions

"""
def print_zobrist_board(zobrist_hex):
    board = ''
    tab = ' '
    for j in range(7): # row, z
        for i in range(-6, 7-j): # col, y, x
            x, y, z = axial_to_cube((j, i))
            pos_zobrist = (x, y, z)
            
            if pos_zobrist in hex_grid:
                zobr = zobrist_hex[pos_zobrist][0] ^ hex_grid[pos_zobrist]
                
                if pos_occupied(x, y, z):
                    if zobr == 5285243159229362636:
                        board += 'B'
                    elif zobr == 9729454471967860433:
                        board += 'W'
                else:
                    board += '_'

                board += ' '


        board += '\n'
        board += tab
        tab += ' '
        
    print(board)  
    return board
 
zobrist_hex = board_to_zobrist()
board = print_zobrist_board(zobrist_hex)
toZobrist(hex_grid)
printBoard(board)
# Out:
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _
#
# _ _ _ _ _ _ B W B B B _ W
#  _ _ _ _ _ _ _ _ _ _ _ W
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ W
#     _ _ _ _ _ _ _ _ W
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _

# %%
# piece_position[(-6, 6, 0)]
# tt = {} # ( (depth, old_board) :[new_board])

# %%
""" Create a zobrist key for the entire board

"""
def toZobrist(hex_grid):
    zobrist_key = 0
    for key in hex_grid:
        zobrist_key ^= hex_grid[key]
        
        if key in piece_position:
#             print(piece_position)
            zobrist_key ^= int(piece_position[key])
            
    return zobrist_key

toZobrist(hex_grid)
# Out:
# 4288134929687727839

# %%
piece_position[(0,0,0)] ^ 9729454471967860433
# Out:
# 14870045864219842333

# %%
def sequentialPlay():
    global hex_grid
    global side
    global depth
#     global tt
    new_zobrist = 0
    
    hex_grid_temp = deepcopy(hex_grid) # copy without references
    
    """Play a sequential game, play row by value

    """
    if check_win():
        print('Already won?: ', check_win(), '\n')
        printBoard(hex_grid)
    else:
        for position in hex_grid:
            x, y, z = position
            moveMade = False

            if not pos_occupied(x, y, z):
                make_move((x, y, z))
                moveMade = True
                
                new_zobrist = toZobrist(hex_grid) ^ rnd.getrandbits(64)

                if check_win():
                    print('Won', (x, y, z), check_win())
                    undo_make_move((x, y, z))
                else:
                    print('No Win', (x, y, z), check_win())
                printBoard(hex_grid)
                tt.setdefault((depth, toZobrist(hex_grid)), []).append(new_zobrist)

            if moveMade:
                undo_make_move((x, y, z))
    depth += 1
    return move_history

def randomPlay():
    global hex_grid
    global side
    hex_grid_temp = deepcopy(hex_grid) # copy without references

    """Play a random game

    """
    if check_win():
        print('Already won?: ', check_win(), '\n')
        printBoard(hex_grid)
    else:
        for n in range(len(hex_grid)): #100
            moveMade = False
            while not moveMade:
                position = rnd.sample(list(hex_grid), 1) #100
                x, y, z = position[0]

                if not pos_occupied(x, y, z):
                    make_move((x, y, z))
                    moveMade = True
                    printBoard(hex_grid)

                    if check_win():
                        print('Won', (x, y, z), check_win())
                        break
                    else:
                        print('No Win', (x, y, z), check_win())

                    side = 'W' if side == 'B' else 'B' # change sides
                        
                    break

    print(move_history)
    
    return move_history   
    
def randomPlay2():
    global hex_grid
    global side
    hex_grid_temp = deepcopy(hex_grid) # copy without references

    x, y, z = 0, 0, 0
    """Play a random game

    """
    if check_win():
        print('Already won?: ', check_win(), '\n')
        printBoard(hex_grid)
    else:
        for n in range(len(hex_grid)+1): #100
            i, j = 0, 0

            valid_move = False
            while not valid_move: 
                i = rnd.randint(-6,6)
                j = rnd.randint(-6, 6-i)
                x, y, z = axial_to_cube((j, i))
                if (x, y, z) in hex_grid and not pos_occupied(x, y, z):
                    valid_move = True
                    make_move((x, y, z))
                    break

            printBoard(hex_grid)

            if check_win():
                print('Won', (x, y, z), check_win())
                break
            else:
                print('No Win', (x, y, z), check_win())

            side = 'W' if side == 'B' else 'B' # change sides

    print(move_history)
    
    return move_history

depth = 1
# randomPlay()
sequentialPlay()

reset()

# import numpy as np
# np.array(hex_grid)[0]
# Out:
# No Win (-6, 6, 0) False
# B _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-5, 5, 0) False
# _ B _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-4, 4, 0) False
# _ _ B _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-3, 3, 0) False
# _ _ _ B _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-2, 2, 0) False
# _ _ _ _ B _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-1, 1, 0) False
# _ _ _ _ _ B _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (0, 0, 0) False
# _ _ _ _ _ _ B _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (1, -1, 0) False
# _ _ _ _ _ _ _ B _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (2, -2, 0) False
# _ _ _ _ _ _ _ _ B _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (3, -3, 0) False
# _ _ _ _ _ _ _ _ _ B _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (4, -4, 0) False
# _ _ _ _ _ _ _ _ _ _ B _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (5, -5, 0) False
# _ _ _ _ _ _ _ _ _ _ _ B _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (6, -6, 0) False
# _ _ _ _ _ _ _ _ _ _ _ _ B
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-6, 5, 1) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  B _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-5, 4, 1) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ B _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-4, 3, 1) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ B _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-3, 2, 1) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ B _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-2, 1, 1) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ B _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-1, 0, 1) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ B _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (0, -1, 1) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ B _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (1, -2, 1) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ B _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (2, -3, 1) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ B _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (3, -4, 1) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ B _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (4, -5, 1) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ B _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (5, -6, 1) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ B
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-6, 4, 2) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   B _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-5, 3, 2) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ B _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-4, 2, 2) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ B _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-3, 1, 2) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ B _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-2, 0, 2) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ B _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-1, -1, 2) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ B _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (0, -2, 2) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ B _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (1, -3, 2) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ B _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (2, -4, 2) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ B _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (3, -5, 2) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ B _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (4, -6, 2) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ B
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-6, 3, 3) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    B _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-5, 2, 3) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ B _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-4, 1, 3) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ B _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-3, 0, 3) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ B _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-2, -1, 3) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ B _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-1, -2, 3) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ B _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (0, -3, 3) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ B _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (1, -4, 3) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ B _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (2, -5, 3) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ B _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (3, -6, 3) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ B
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-6, 2, 4) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     B _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-5, 1, 4) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ B _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-4, 0, 4) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ B _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-3, -1, 4) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ B _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-2, -2, 4) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ B _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (0, -6, 6) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ B
#
# No Win (0, -4, 4) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ B _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (1, -5, 4) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ B _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (2, -6, 4) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ B
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-6, 1, 5) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      B _ _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-5, 0, 5) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ B _ _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-4, -1, 5) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ B _ _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-3, -2, 5) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ B _ _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-2, -3, 5) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ B _ _ _
#       _ _ _ _ _ _ _
#
# No Win (-1, -4, 5) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ B _ _
#       _ _ _ _ _ _ _
#
# No Win (0, -5, 5) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ B _
#       _ _ _ _ _ _ _
#
# No Win (1, -6, 5) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ B
#       _ _ _ _ _ _ _
#
# No Win (-6, 0, 6) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       B _ _ _ _ _ _
#
# No Win (-5, -1, 6) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ B _ _ _ _ _
#
# No Win (-4, -2, 6) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ B _ _ _ _
#
# No Win (-2, -4, 6) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ B _ _
#
# No Win (-1, -5, 6) False
# _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _
#   _ _ _ _ _ _ _ _ _ _ _
#    _ _ _ _ _ _ _ _ _ _
#     _ _ _ _ _ _ _ _ _
#      _ _ _ _ _ _ _ _
#       _ _ _ _ _ B _

# %%
tt
# Out:
# {(1, 8276058491019771667): [13949136138600165451,
#   18292553436446930671,
#   3804116256544303721,
#   16708814793875475748,
#   17741458935571493028,
#   5482470957350021315,
#   9354260936894075439,
#   9488538099278886178,
#   6188009180044081925,
#   5885312341842245449,
#   2843134555016852698,
#   10785111484418357595,
#   9439625211748000067,
#   9909685975762436265,
#   7141219195108224856,
#   11063464519160904036,
#   733916853411063565,
#   7749854108357142780,
#   8991443990343449201,
#   8127985445969587136,
#   7074618596098669434,
#   7971145149405674089,
#   12275314215002825789,
#   3262599579547610757,
#   10745016980218628603,
#   9694511337581882011,
#   4419847600609336701,
#   11377130356254085933,
#   11918952726649279760,
#   7752803696721682631,
#   796345145874677462,
#   3541128752117204182,
#   13661274386144372089,
#   13922451730570521458,
#   2832845171096693987,
#   13208795305696210176,
#   4852641324325014299,
#   12437562681813588642,
#   12594558694357751406,
#   17101178402329103337,
#   3124594140315967563,
#   11944115947965505382,
#   5538978361519481270,
#   2482710331310287047,
#   519842180961977837,
#   465537041987499502,
#   18389562459162966374,
#   4895732453202855775,
#   8240630720018161403,
#   9243815507249672875,
#   479788859683081080,
#   1896120563451900943,
#   2972283826526279500,
#   7391528961730669363,
#   3499727497422621561,
#   9249856922793591030,
#   6594496869230144886,
#   5244525702285781815],
#  (1, 13584955121103644686): [15336883669272089041,
#   11129064279907929751,
#   5509773966769644326,
#   7561454944958068925,
#   11852357217931491392,
#   7430597814221294069,
#   7924526310394467464,
#   17405707548803097716,
#   4304900395709482747,
#   6658238128290078188,
#   5919556724831505541,
#   6018367993888282376,
#   9209620802597222825,
#   13856381162737460648,
#   13840919581252320201,
#   8210577063680232731,
#   3304027223312922399,
#   11328961923725020054,
#   1626848834482333532,
#   16775194587301387500,
#   3744912209933321434,
#   14499173485600534767,
#   11585092771305626938,
#   1468690272898805036,
#   12551078985834779288,
#   1512608006723660785,
#   11238544720405596285,
#   5837469899130507235,
#   6360443231701797748,
#   16799575928224444680,
#   10033022339390517447,
#   9520081468011426968,
#   15091189110861545496,
#   11706962829851018750,
#   7934039182153010748,
#   9673280153336326750,
#   5676022843588432800,
#   14065752999017575510,
#   13087250613465854532,
#   8431990763240574772,
#   287018413565779585,
#   11254293109031918772,
#   11791879853495838947,
#   1262213307395759566,
#   8398500134677809156,
#   16307459324272676592,
#   7495659051146539217,
#   14391784269766663783,
#   11561987071860046177,
#   13591909270921515209,
#   16230329023782566514,
#   9187226999574949340,
#   11239881295432091239,
#   14966984886879168252,
#   7059537978766234610,
#   8485491781190055312,
#   18200609668197419198,
#   11410103700841069394,
#   13078101713286972787,
#   8054230608756745040,
#   5790447051250603954,
#   10210566274891034157,
#   16321234499782540223,
#   8291321459741306535,
#   13744698000607426164,
#   18237620105399399903,
#   15809789594442202414,
#   10577054378757388644,
#   4884167772343070348,
#   3734130988437426557,
#   2245371486051064559,
#   1593202714424354316,
#   9305721867176316612,
#   384650507948627134,
#   13498472191152241736,
#   8859319652227969378,
#   4246755724543295380,
#   6323800700430679569,
#   15572464339226024706,
#   10350336224150248983,
#   15071234128723063289,
#   13012563391598806480,
#   1641565547503703277,
#   13333779261476240337,
#   4267941481334986341,
#   10425358040770687776,
#   5250377170985795525,
#   3346275137298748651,
#   9501049205444895128,
#   5943089813848035782,
#   12719294424957871099,
#   8868506308022011276,
#   4699149591415433934,
#   14073720154999767813,
#   15971093514862483283,
#   4395636675328972812,
#   10784762202048723494,
#   1302976405747510970,
#   17985778633893673476,
#   6307334619220532255,
#   4615798603436507444,
#   16462085833710443316,
#   966036270992896738,
#   895559751408114122,
#   10819011113027105250,
#   689424055132297814,
#   9488994719387258346,
#   7022771538281568055,
#   13777849854720885026,
#   4189718818622331875,
#   13273842337043092887,
#   6199201131871568808,
#   16551600093570106453,
#   3885998793101603495,
#   600283488763262739,
#   16776433070791973767,
#   16221146848334010243,
#   11242845396381798629,
#   4039322982317822965,
#   9185514965897175169,
#   9169354520835510526,
#   4783485775804694606,
#   9299075286438716513,
#   9839984974130743410,
#   15923631499332501638,
#   2137071083428089499,
#   16264248078192358283,
#   17295573722880411497,
#   3869527825904898555,
#   8811674954488695292,
#   17842156415541021382,
#   5570438432148242003,
#   10488067538586360617,
#   5724981316120009343,
#   12449551367160253939,
#   16685717887961599444,
#   5391846033902288120,
#   1373448443605305582,
#   5629639078131604989,
#   16238718143928352615,
#   1214382759633351640,
#   6226564368095884385,
#   7453416654278313127,
#   11729455967007854869,
#   13167238628020024277,
#   936734211426235002,
#   2578111207209596892,
#   15898490598297298296,
#   4163292079915913816,
#   3775100548435966681,
#   3369722931003236562,
#   15926373444456545282,
#   8198674210784968847,
#   16807188397818212557,
#   5348337534379783059,
#   4958565724855858798,
#   17861760697420617789,
#   15458092008830769130,
#   18430075932328199183,
#   10383564150576853573,
#   8110842457922944530,
#   10125790404571865070,
#   6336419551678227284,
#   453726369257961555,
#   7721207664189629942,
#   8733815391125262186,
#   18048533602125818024,
#   13378832545730716029,
#   17594770785060976855,
#   13393301059128902691,
#   958367214883238081,
#   12861903627156138152,
#   1873711559759947493,
#   15147643026351854163,
#   13279467041686652671,
#   15830163349116621218,
#   6072012606608879726,
#   14046993628294904598,
#   17667510794379737390,
#   4151426306541945152,
#   16865340502777836906,
#   18426687631629479784,
#   9116502177366022130,
#   8438565359166332548,
#   15352794563596395680,
#   18064250038034298535,
#   4566587051792180985,
#   17605621944741739631,
#   3283687604007749293,
#   17181282467409277523,
#   4233760651402616214,
#   2914776479742826521,
#   4674191985205971320,
#   14223680820205133691,
#   5270068647685110282,
#   4771465536784129917,
#   2573446779634785394,
#   12917282990921570028,
#   6561004226093263080,
#   12469429744860055369,
#   3358674826681628943,
#   8111775422914498453,
#   9157534761480471613,
#   17007418721050016493]}

# %%
def main(select):
    print(select)
    if select == 1: return 1 # h vs h
    elif select == 2: return 2 # m vs h
    elif select == 3: return 3 # h vs m
    elif select == 4: print (4) # m vs m
    return 0
    
if '__name__' == '__main__':
    main(4)

# %%
# import time

# print ("time.time(): %f " % time.time())
# print (time.ctime(int( 1514962335.2237754)))
# print (time.asctime( time.localtime(1516961409.8324103) ))
# print ((time.time() - 1514962335.2237754)/60/60)

# %%
# d = [rnd.randint(0, 10) for i in range(10)]

# import sys

# CURSOR_UP_ONE = '\x1b[1A'
# ERASE_LINE = '\x1b[2K'

# counter = ''
# for i in d:
#     counter += '-'
#     sys.stdout.write(counter + '\n'+CURSOR_UP_ONE)
#     sys.stdout.write(ERASE_LINE)
